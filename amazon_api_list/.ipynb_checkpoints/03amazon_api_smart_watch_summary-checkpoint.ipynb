# %% [markdown]
# # 価格vs評価

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
listbands = pd.read_csv("amazon_listband.csv")
rev = pd.read_csv("review_data.csv")
print(listbands.head())
print(rev.head())
# Out:
#          asin date manufacturer   price      rank
# 0  B01GPMWF2W  NaN          ダッカ   380.0  308934.0
# 1  B018VOMC98  NaN          UEB   500.0  879805.0
# 2  B013XY4LPY  NaN        asian  1000.0   50365.0
# 3  B01GMELSQ2  NaN       Pinhen  1200.0  168151.0
# 4  B013XYAWOI  NaN        asian  1000.0  145673.0
#          asin  average_rate  num_of_rate  \
# 0  B01GPMWF2W           0.0            0
# 1  B013XY4LPY           2.0            1
# 2  B01GMELSQ2           4.0            1
# 3  B000CSOV96           0.0            0
# 4  B0122BADGK           3.6           34
#
#                                           review_url
# 0  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 1  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 2  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 3  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 4  http://www.amazon.jp/reviews/iframe?akid=AKIAI...

# %%
listbands = listbands.set_index("asin",drop=True)
rev = rev.set_index("asin",drop=True)

# %%
all_data = pd.concat([listbands,rev],axis=1,join='inner')
all_data.to_csv('api_data_listbands.csv')

# %% [markdown]
# # 価格と評価の関係
# - 縦軸平均評価
# - 横軸価格
# - 評価回数が1回以上、5回以上、10回以上の3段階で整理

# %%
fig = plt.figure(figsize=(8,12))
ax1 = fig.add_subplot(3,1,1)
ax2 = fig.add_subplot(3,1,2)
ax3 = fig.add_subplot(3,1,3)

ax1.scatter(all_data[all_data["num_of_rate"]>0]["price"],
            all_data[all_data["num_of_rate"]>0]["average_rate"])
ax2.scatter(all_data[all_data["num_of_rate"]>4]["price"],
            all_data[all_data["num_of_rate"]>4]["average_rate"])
ax3.scatter(all_data[all_data["num_of_rate"]>9]["price"],
            all_data[all_data["num_of_rate"]>9]["average_rate"])
ax1.set(ylabel="average_rate",title="number of rate >= 1")
ax2.set(ylabel="average_rate",title="number of rate >= 5")
ax3.set(ylabel="average_rate",title="number of rate >= 10",xlabel="price(yen)")

sns.plt.show()

# %%
all_data = all_data.dropna(subset=["price",])

# %% [markdown]
# - 価格の高い安いと、評価の高い低いは関係がない模様
# - 評価回数が1つの場合、評価が5または1の場合があるので、以降は除外

# %% [markdown]
# # 評価件数が5件以上の場合の線形回帰

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(all_data[all_data["num_of_rate"]>4][["price"]],
          all_data[all_data["num_of_rate"]>4]["average_rate"])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
from scipy.stats import linregress
slope,intercept,r_value,p_value,std_err = linregress(all_data[all_data["num_of_rate"]>4]["price"],
                                                     all_data[all_data["num_of_rate"]>4]["average_rate"])
print("切片:%0.2f") %intercept
print("回帰係数:%0.6f") %slope
print("決定係数:%0.2f") %model.score(all_data[all_data["num_of_rate"]>4][["price"]],
                                 all_data[all_data["num_of_rate"]>4]["average_rate"])
print("p値:%0.5f") %p_value
print("\n相関係数:%0.2f") %r_value
# Out:
# 切片:3.34
# 回帰係数:0.000013
# 決定係数:0.02
# p値:0.13717
#
# 相関係数:0.14

# %%
plt.scatter(all_data[all_data["num_of_rate"]>4]["price"],
            all_data[all_data["num_of_rate"]>4]["average_rate"])
plt.plot(all_data[all_data["num_of_rate"]>4][["price"]],
        model.predict(all_data[all_data["num_of_rate"]>4][["price"]]),c="r")
plt.xlabel("price")
plt.ylabel("average_rate")

sns.plt.show()

# %% [markdown]
# # 評価件数10件以上の線形回帰

# %%
model = LinearRegression()
model.fit(all_data[all_data["num_of_rate"]>9][["price"]],
          all_data[all_data["num_of_rate"]>9]["average_rate"])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
from scipy.stats import linregress
slope,intercept,r_value,p_value,std_err = linregress(all_data[all_data["num_of_rate"]>9]["price"],
                                                     all_data[all_data["num_of_rate"]>9]["average_rate"])
print("切片:%0.2f") %intercept
print("回帰係数:%0.6f") %slope
print("決定係数:%0.2f") %model.score(all_data[all_data["num_of_rate"]>9][["price"]],
                                 all_data[all_data["num_of_rate"]>9]["average_rate"])
print("p値:%0.5f") %p_value
print("\n相関係数:%0.2f") %r_value
# Out:
# 切片:3.43
# 回帰係数:0.000009
# 決定係数:0.01
# p値:0.24768
#
# 相関係数:0.12

# %%
plt.scatter(all_data[all_data["num_of_rate"]>9]["price"],
            all_data[all_data["num_of_rate"]>9]["average_rate"])
plt.plot(all_data[all_data["num_of_rate"]>9][["price"]],
        model.predict(all_data[all_data["num_of_rate"]>9][["price"]]),c="r")
plt.xlabel("price")
plt.ylabel("average_rate")

sns.plt.show()

# %% [markdown]
# # 評価件数をパラメータに使って分析
# - 横軸評価件数
# - 縦軸、回帰係数、決定係数、p値、相関係数

# %%
stats = []
for i in np.linspace(5,50,46):
    slope,intercept,r_value,p_value,std_err = linregress(all_data[all_data["num_of_rate"] >= i]["price"],
                                                     all_data[all_data["num_of_rate"] >= i]["average_rate"])
    model = LinearRegression()
    model.fit(all_data[all_data["num_of_rate"] >= i][["price"]],
              all_data[all_data["num_of_rate"] >= i]["average_rate"])
    determin = model.score(all_data[all_data["num_of_rate"] >= i][["price"]],
                           all_data[all_data["num_of_rate"] >= i]["average_rate"])
    stats.append([i,slope,intercept,determin,r_value,p_value,std_err])
columns=['number','slope','intercept','determin','r_value','p_value','std_err']
stats_df = pd.DataFrame(stats,columns=columns)

# %%
fig = plt.figure(figsize=(10,10))
ax1 = fig.add_subplot(3,2,1) #slope
ax2 = fig.add_subplot(3,2,2) #determin
ax3 = fig.add_subplot(3,2,3) #p_value
ax4 = fig.add_subplot(3,2,4) #r_value

ax1.scatter(stats_df["number"],stats_df["slope"])
ax1.set(ylabel="slope")
ax2.scatter(stats_df["number"],stats_df["determin"])
ax2.set(ylabel="coefficient of determination")
ax3.scatter(stats_df["number"],stats_df["p_value"])
ax3.plot([5,50],[0.05,0.05],ls=":",c='r')
ax3.set(ylabel="p_value",xlabel="number of rates")
ax4.scatter(stats_df["number"],stats_df["r_value"])
ax4.set(ylabel="r_value",xlabel="number of rates")
sns.plt.show()

# %% [markdown]
# - 回帰係数は評価件数を増やしても変化なし
# - 回帰係数のp値は評価件数が17件〜29件で0.05を超える
# - 決定係数、相関係数は30件を超えると値が急増する
# - 評価件数が30件以上のデータ数は32個

# %% [markdown]
# # 評価件数30件

# %%
model = LinearRegression()
model.fit(all_data[all_data["num_of_rate"] >29][["price"]],
          all_data[all_data["num_of_rate"] >29]["average_rate"])
plt.scatter(all_data[all_data["num_of_rate"]>29]["price"],
            all_data[all_data["num_of_rate"]>29]["average_rate"])
plt.plot(all_data[all_data["num_of_rate"]>29][["price"]],
        model.predict(all_data[all_data["num_of_rate"]>29][["price"]]),c="r")
plt.xlabel("price")
plt.ylabel("average_rate")

sns.plt.show()
