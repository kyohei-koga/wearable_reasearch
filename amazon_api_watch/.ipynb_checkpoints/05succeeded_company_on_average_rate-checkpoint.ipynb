# %% [markdown]
# # 成功企業と非成功企業の技術区分別傾向の比較
#
# ### サマリー
# - レビュー件数が10件以上で、かつ、レビュー値が4.0以上の企業を成功企業とした。→ペブル、サムスン、エイサス
# - 非成功企業はレビュー値4.0未満の中でレビュー値の大きい順に3社選択した。→モトローラ、ソニー、ファーウェイ
# - 操作性の向上、ディスプレイの技術区分では成功企業が活発
# - CPU、ユーザー状態の技術区分では非成功企業が活発
# - 成功企業は性能の向上よりも使いやすさや見やすさを追求している？
#
# ### 課題
# - 各種検定（レビュー値、区分ごとの出願）
# - 成功企業がほとんどサムスンの出願で占められている。

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data_amazon = pd.read_csv("api_data_smart_watches.csv")
data_wearable = pd.read_csv("/home/kyohei/wearable/data/01.文献リスト_特許.csv",encoding="SHIFT-JIS")
categories = pd.read_csv("/home/kyohei/wearable/data/T_小区分.csv",encoding="SHIFT-JIS")

# %% [markdown]
# # サンプル企業の抽出
# - レビュー値に閾値を用いて成功企業を3社抽出
# - 閾値以下の中から非成功企業を3社抽出

# %%
#レビュー件数の設定:10
num_of_rev = 10
suc_data_ama = data_amazon[data_amazon['num_of_rate'] >= num_of_rev]
#レビュー値の設定:4.0
rev_value = 4.
suc_data_ama = suc_data[suc_data['average_rate'] >= rev_value]
suc_data_ama.sort_values('average_rate',ascending=False)
# Out:
#            asin        date manufacturer    price      rank  average_rate  \
# 479  B019BX83B4  2015-12-18    by Galaxy  41979.0  192578.0           4.6
# 480  B019BX83T6  2015-12-18    by Galaxy  42000.0   29626.0           4.6
# 512  B01ET2OQB8  2016-04-22    by Galaxy  58697.0   78758.0           4.6
# 332  B00Y2CYZ5I         NaN       Pebble  16600.0   26927.0           4.5
# 567  B00Y2CYYQ8         NaN       Pebble  14425.0    1245.0           4.5
# 13   B01CU1QZR8         NaN      EloBeth   1764.0   13690.0           4.4
# 11   B01CU1RS42         NaN      EloBeth   1658.0   14655.0           4.3
# 465  B019SXHB38         NaN      Samsung  35980.0   30326.0           4.3
# 241  B00H7ASLVG         NaN       Pebble  10500.0    6600.0           4.2
# 267  B00IW05H2Q         NaN       Pebble  11980.0   57716.0           4.2
# 216  B01GJ0YTLK         NaN          OEM   9999.0   19270.0           4.1
# 607  B00BKEQBI0         NaN       Pebble  10970.0   74460.0           4.1
# 370  B00OXDS34K  2014-11-21      ASUSTek  19600.0  103541.0           4.0
#
#      num_of_rate                                         review_url
# 479           16  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 480           16  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 512           16  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 332           59  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 567           59  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 13            14  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 11            11  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 465           18  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 241           79  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 267           79  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 216           12  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 607           56  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 370           28  http://www.amazon.jp/reviews/iframe?akid=AKIAI...

# %%
fale_data_ama = data_amazon[(data_amazon['num_of_rate'] >= num_of_rev) & (data_amazon['average_rate'] < rev_value)]
fale_data_ama.sort_values('average_rate',ascending=False).head(30)
# Out:
#            asin        date        manufacturer    price      rank  \
# 0    B00XMUYASS         NaN  Leesentec(リーセンテック)    799.0   12795.0
# 302  B00IYEBE8G         NaN                 NaN  14800.0   14075.0
# 392  B00PD8JY60         NaN            Motorola  22800.0  120869.0
# 382  B00OUEN9IC         NaN            Motorola  22780.0   67331.0
# 369  B00PC7PDSA         NaN            Motorola  19979.0    7198.0
# 483  B015Z7O73I  2015-10-16              HUAWEI  44060.0    5911.0
# 434  B00OBHEQF8         NaN            Motorola  27980.0  145289.0
# 507  B015Z7O0UI  2015-10-16              HUAWEI  55824.0   91807.0
# 510  B015Z7O40E  2015-10-16              HUAWEI  56808.0   98731.0
# 499  B016COOLFC         NaN            Motorola  49980.0   23278.0
# 494  B016COOLGQ         NaN            Motorola  47800.0    4427.0
# 439  B01AHEDERY         NaN            Motorola  28500.0  190886.0
# 476  B016COOLKW         NaN            Motorola  40200.0  152063.0
# 468  B014UMHGU0         NaN            Motorola  36400.0   32220.0
# 511  B016COOLHA         NaN            Motorola  58605.0  142154.0
# 515  B016COOLG6         NaN            Motorola  69999.0  297463.0
# 584  B01AHEDESS         NaN            Motorola  27998.0   12479.0
# 464  B016COOLH0         NaN            Motorola  35190.0   64619.0
# 487  B016COOLIE         NaN            Motorola  45800.0   15521.0
# 451  B01AHEDES8         NaN            Motorola  31800.0   24919.0
# 290  B00DNDF2OU         NaN                Sony  13200.0    5551.0
# 316  B010UV1XIG  2015-07-30            Withings  15109.0   11414.0
# 291  B00IVX0XGO         NaN              Pebble  13390.0   27092.0
# 604  B00XMTMTYG         NaN  Leesentec(リーセンテック)    799.0   59600.0
# 170  B00N2NLB6Y         NaN                null   6896.0   56726.0
# 393  B00N9OAQI0         NaN                 ソニー  22380.0    8231.0
# 578  B018ORDSC2         NaN              HUAWEI  19000.0   67602.0
# 283  B013I0QNEA         NaN               OZONE  12980.0  182269.0
# 526  B015DNYFUE         NaN       Shenzhen Wave   1999.0   27697.0
# 572  B0169RUJRQ         NaN                Sony  15500.0    8564.0
#
#      average_rate  num_of_rate  \
# 0             3.9           10
# 302           3.9           25
# 392           3.9          112
# 382           3.9          112
# 369           3.9          112
# 483           3.9           23
# 434           3.9          112
# 507           3.9           23
# 510           3.9           23
# 499           3.8           34
# 494           3.8           34
# 439           3.8           34
# 476           3.8           34
# 468           3.8           34
# 511           3.8           34
# 515           3.8           34
# 584           3.8           34
# 464           3.8           34
# 487           3.8           34
# 451           3.8           34
# 290           3.8           75
# 316           3.6           83
# 291           3.6           15
# 604           3.6           12
# 170           3.5          111
# 393           3.5           44
# 578           3.5          123
# 283           3.5           13
# 526           3.5           11
# 572           3.4           18
#
#                                             review_url
# 0    http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 302  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 392  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 382  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 369  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 483  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 434  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 507  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 510  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 499  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 494  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 439  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 476  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 468  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 511  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 515  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 584  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 464  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 487  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 451  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 290  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 316  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 291  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 604  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 170  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 393  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 578  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 283  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 526  http://www.amazon.jp/reviews/iframe?akid=AKIAI...
# 572  http://www.amazon.jp/reviews/iframe?akid=AKIAI...

# %% [markdown]
# ### 成功企業
# - pebble,samusung,asus
#
# ### 非成功企業
# - motorola,Huawei,sony

# %%
company_suc = [u"サムスン",u"ASUSTEK COMPUTER INC.",u"ペブルテクノロジー"]
company_fal = [u"モトローラ",u"ソニー",u"ファーウェイ"]
data_suc_pat = data_wearable[data_wearable[u"筆頭出願人名"].isin(company_suc)]
data_fal_pat = data_wearable[data_wearable[u"筆頭出願人名"].isin(company_fal)]

# %%
data_suc_pat_watch = data_suc_pat[data_suc_pat[u"B0302"]==1]
data_fal_pat_watch = data_fal_pat[data_fal_pat[u"B0302"]==1]
print("成功企業の内訳\n%s"%data_suc_pat_watch[u'筆頭出願人名'].value_counts())
print("\n非成功企業の内訳\n%s"%data_fal_pat_watch[u'筆頭出願人名'].value_counts())
# Out:
# 成功企業の内訳
# サムスン                     134
# ASUSTEK COMPUTER INC.      5
# ペブルテクノロジー                  1
# Name: 筆頭出願人名, dtype: int64
#
# 非成功企業の内訳
# ソニー       36
# モトローラ      9
# ファーウェイ     1
# Name: 筆頭出願人名, dtype: int64

# %%
data_suc_cal = data_suc_pat_watch.iloc[:,19:].count() / float(data_suc_pat_watch.shape[0])
data_fal_cal = data_fal_pat_watch.iloc[:,19:].count() / float(data_fal_pat_watch.shape[0])

# %%
compare_category = pd.concat([data_suc_cal,data_fal_cal],axis=1)
compare_category.rename(columns={0:"succeed",1:"fale"},inplace=True)
compare_category["diff"] = abs(compare_category["succeed"] - compare_category["fale"])

categories = categories.set_index(u"記号",drop=True)
compare_category = pd.concat([compare_category,categories],axis=1)

# %%
comapre_category_sigdiff = compare_category[compare_category['diff'] >= 0.2].sort_values('diff',ascending=False)
comapre_category_sigdiff
# Out:
#         succeed      fale      diff                          小区分
# D0302  0.085714  0.434783  0.349068                  中央演算装置（CPU）
# B9998  0.378571  0.043478  0.335093                     種別に関し非限定
# C0104  0.500000  0.173913  0.326087                       操作性の向上
# G0105  0.071429  0.391304  0.319876                         サーバー
# D0398  0.371429  0.086957  0.284472          演算・インターフェイス装置に関し非限定
# I0601  0.000000  0.282609  0.282609                   お知らせ・注意・指示
# C0107  0.050000  0.326087  0.276087                 ユーザー状態の正確な把握
# B0198  0.328571  0.065217  0.263354                HMD・眼鏡型に関し非限定
# J0403  0.000000  0.260870  0.260870  スポーツ施設（競技場、練習場、フィットネスクラブなど）
# H0302  0.014286  0.260870  0.246584                           健康
# D0702  0.064286  0.304348  0.240062                         WiＦｉ
# F0205  0.000000  0.239130  0.239130                           発汗
# F0602  0.000000  0.239130  0.239130                           湿度
# D0501  0.714286  0.478261  0.236025                       ディスプレイ
# D0703  0.071429  0.304348  0.232919                    BlueＴooth
# A0102  0.550000  0.782609  0.232609         オートノマス・ウェアラブル・コンピュータ
# A0198  0.421429  0.195652  0.225776            パッシブ・オートノマスに関し非限定
# H0102  0.392857  0.173913  0.218944                   BtoC（個人向け）
# I0506  0.000000  0.217391  0.217391                           距離
# I0504  0.000000  0.217391  0.217391                           地形
# I0499  0.000000  0.217391  0.217391                    その他の気象データ
# I0403  0.000000  0.217391  0.217391                           湿度
# I0402  0.000000  0.217391  0.217391                           温度
# B0702  0.000000  0.217391  0.217391                           上着
# F0699  0.000000  0.217391  0.217391          その他のクライメイト（気候）・センサー
# F0106  0.071429  0.282609  0.211180                  方向・傾き（ジャイロ）
# F0401  0.050000  0.260870  0.210870                      位置（GPS)
# F0601  0.028571  0.239130  0.210559                           温度
# B0301  0.164286  0.369565  0.205280                      リストバンド型
# I0103  0.142857  0.347826  0.204969                    ユーザ音声（入力）
# F0102  0.100000  0.304348  0.204348                          加速度
# F0201  0.035714  0.239130  0.203416                           心拍
# C0110  0.014286  0.217391  0.203106                運動・勉強などへの動機付け
