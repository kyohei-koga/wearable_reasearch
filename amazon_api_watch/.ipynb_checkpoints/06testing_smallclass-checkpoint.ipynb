# %%
# coding: shift-jis
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data_amazon = pd.read_csv('api_data_smart_watches.csv')
# Out:
# /home/kyohei/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %% [markdown]
# # レビュー値の分布より企業分類
# - レビュー件数が10件以上が対象
# - 成功企業はレビュー値が4.0以上の企業→サムスン、エイサス、ペブル
# - 比較対象はレビュー値が3.5以上、3.8以下の企業→ソニー、モトローラ、ファーウェイ

# %%
data_amazon.columns
# Out:
# Index([u'asin', u'date', u'manufacturer', u'price', u'rank', u'average_rate',
#        u'num_of_rate', u'review_url'],
#       dtype='object')

# %%
fig = plt.figure(figsize=(15,4))
ax1 = fig.add_subplot(1,3,1)
ax2 = fig.add_subplot(1,3,2)
ax3 = fig.add_subplot(1,3,3)
data_amazon[data_amazon['num_of_rate'] >= 10].hist('average_rate',ax=ax1,bins=10)
data_amazon[data_amazon['num_of_rate'] >= 20].hist('average_rate',ax=ax2,bins=10)
data_amazon[data_amazon['num_of_rate'] >= 30].hist('average_rate',ax=ax3,bins=10)
ax1.set_xlabel("num of rate = 10",fontsize=15)
ax2.set_xlabel("num of rate = 20",fontsize=15)
ax3.set_xlabel("num of rate = 30",fontsize=15)
plt.show()

# %%
data_10 = data_amazon[data_amazon[u'num_of_rate'] >= 10]
#succeed
suc = data_10[data_10['average_rate']>=4.0]
print('succeeded companies are \n%s') %suc[u'manufacturer'].unique()
#normal
normal = data_10[(data_10['average_rate'] >= 3.5) & (data_10['average_rate'] <= 3.8)]
print('\nnormal companies are \n%s') %str(normal[u'manufacturer'].unique()).decode('string-escape')
#fale
fale = data_10[data_10['average_rate'] < 3.5]
print('\nfalse companies are \n%s') %str(fale[u'manufacturer'].unique()).decode('string-escape')
# Out:
# succeeded companies are
# ['EloBeth' 'OEM' 'Pebble' 'ASUSTek' 'Samsung' 'by Galaxy']
#
# normal companies are
# ['null' 'OZONE' 'Sony' 'Pebble' 'Withings'
#  'ソニー' 'Motorola' 'Shenzhen Wave' 'HUAWEI'
#  'Leesentec(リーセンテック)']
#
# false companies are
# ['Shenzhen Wave' 'STK'
#  'ネット販売専門'
#  'Eagle　Eye' 'MisSmart'
#  'Sleep tracker(スリープトラッカー)'
#  nan 'Sony' 'Sincere　Inc.' 'Withings' 'Samsung']

# %% [markdown]
# # 分析

# %%
company_suc = [u'サムスン',u'ASUSTEK COMPUTER INC.','ペブルテクノロジー']
company_nor = [u'モトローラ',u'ソニー',u'ファーウェイ']
data_pat = pd.read_csv('/home/kyohei/wearable/data/01.文献リスト_特許.csv',encoding='SHIFT-JIS')
categories = pd.read_csv('/home/kyohei/wearable/data/T_小区分.csv',encoding='SHIFT-JIS')
data_suc_pat = data_pat[data_pat[u"筆頭出願人名"].isin(company_suc)]
data_fal_pat = data_pat[data_pat[u"筆頭出願人名"].isin(company_nor)]
# Out:
# /home/kyohei/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2902: DtypeWarning: Columns (16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data_suc_pat_watch = data_suc_pat[data_suc_pat[u"B0302"]==1]
data_fal_pat_watch = data_fal_pat[data_fal_pat[u"B0302"]==1]
print("成功企業の内訳\n%s"%data_suc_pat_watch[u'筆頭出願人名'].value_counts())
print("\n非成功企業の内訳\n%s"%data_fal_pat_watch[u'筆頭出願人名'].value_counts())
# Out:
# 成功企業の内訳
# サムスン                     134
# ASUSTEK COMPUTER INC.      5
# Name: 筆頭出願人名, dtype: int64
#
# 非成功企業の内訳
# ソニー       36
# モトローラ      9
# ファーウェイ     1
# Name: 筆頭出願人名, dtype: int64

# %%
data_suc_cal = data_suc_pat_watch.iloc[:,19:].count() / float(data_suc_pat_watch.shape[0])
data_fal_cal = data_fal_pat_watch.iloc[:,19:].count() / float(data_fal_pat_watch.shape[0])
compare_category = pd.concat([data_suc_cal,data_fal_cal],axis=1)
compare_category.rename(columns={0:"succeed",1:"normal"},inplace=True)
compare_category["diff"] = compare_category["succeed"] - compare_category["normal"]
compare_category["diff_abs"] = abs(compare_category["succeed"] - compare_category["normal"])

categories = categories.set_index(u"記号",drop=True)
compare_category = pd.concat([categories,compare_category],axis=1)

# %% [markdown]
# # 検定
# - ２×２クロス表のχ二乗検定
# - 従属変数：当該技術区分に該当する文献か否か（質的変数）
# - 検定の対象となる統計量：比率の差
# - 独立変数の数：1
# - 独立変数の種類：企業の種類
# - 条件数：2
# - 条件の名称：成功企業、非成功企業
# - 対応の有無：無

# %%
data_suc_pat_watch['succeed'] = 1
data_fal_pat_watch['succeed'] = 0

data_all = pd.concat([data_suc_pat_watch,data_fal_pat_watch])
data_all = data_all.fillna(0)

data_all_cal = data_all.iloc[:,19:]
data_all_cal = data_all_cal.loc[:,((data_all_cal.sum() > 0) & (data_all_cal.sum() < data_all_cal.shape[0]))]

from scipy.stats import chi2_contingency
data_all_cal.columns[:-1]
pvalues = []
columns = data_all_cal.columns[:-1]
for row in columns:
    table = pd.crosstab(data_all_cal['succeed'],data_all_cal[row])
    chisq_value,pvalue,df,expected = chi2_contingency(table,correction=False) #補正無し:correction=False
    pvalues.append([row,pvalue,chisq_value,df])

pvalues_df = pd.DataFrame(np.array(pvalues)[:,1],index=np.array(pvalues)[:,0],columns=['pvalue'])
compare_category = pd.concat([compare_category,pvalues_df],axis=1)
compare_category['pvalue'] = compare_category['pvalue'].astype(float)
# Out:
# /home/kyohei/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /home/kyohei/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %% [markdown]
# ### プラス域

# %%
compare_category.sort_values('diff',ascending=False).head(20).style.bar(subset=['succeed','normal','diff_abs'],color='#d65f5f')
# Out:
#         <style  type="text/css" >
#
#
#             #T_4e7a3ca2_4ca6_11e6_8b06_0c84dc86267brow0_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 47.7272727273%, transparent 0%);
#
#             }
#
#             #T_4e7a3ca2_4ca6_11e6_8b06_0c84dc86267brow0_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 9.09090909091%, transparent 0%);
#
#             }
#
#             #T_4e7a3ca2_4ca6_11e6_8b06_0c84dc86267brow0_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#
#             }
#
#             #T_4e7a3ca2_4ca6_11e6_8b06_0c84dc86267brow1_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 67.0454545455%, transparent 0%);
#
#             }
#
#             #T_4e7a3ca2_4ca6_11e6_8b06_0c84dc86267brow1_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 36.3636363636%, transparent 0%);
#
#             }
#
#             #T_4e7a3ca2_4ca6_11e6_8b06_0c84dc86267brow1_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 96.8731208659%, transparent 0%);
#
#             }
#
#             #T_4e7a3ca2_4ca6_11e6_8b06_0c84dc86267brow2_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 46.5909090909%, transparent 0%);
#
#             }
#
#             #T_4e7a3ca2_4ca6_11e6_8b06_0c84dc86267brow2_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 18.1818181818%, transparent 0%);
#
#             }
#
#             #T_4e7a3ca2_4ca6_11e6_8b06_0c84dc86267brow2_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 80.5171377029%, transparent 0%);
#
#             }
#
#             #T_4e7a3ca2_4ca6_11e6_8b06_0c84dc86267brow3_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 39.7727272727%, transparent 0%);
#
#             }
#
#             #T_4e7a3ca2_4ca6_11e6_8b06_0c84dc86267brow3_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 13.6363636364%, transparent 0%);
#
#             }
#
#             #T_4e7a3ca2_4ca6_11e6_8b06_0c84dc86267brow3_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 72.2790138304%, transparent 0%);
#
#             }
#
#             #T_4e7a3ca2_4ca6_11e6_8b06_0c84dc86267brow4_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#
#             }
#
#             #T_4e7a3ca2_4ca6_11e6_8b06_0c84dc86267brow4_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#
#             }
#
#             #T_4e7a3ca2_4ca6_11e6_8b06_0c84dc86267brow4_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 60.0721587492%, transparent 0%);
#
#             }
#
#             #T_4e7a3ca2_4ca6_11e6_8b06_0c84dc86267brow5_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 54.5454545455%, transparent 0%);
#
#             }
#
#             #T_4e7a3ca2_4ca6_11e6_8b06_0c84dc86267brow5_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 40.9090909091%, transparent 0%);
#
#             }
#
#             #T_4e7a3ca2_4ca6_11e6_8b06_0c84dc86267brow5_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 58.0877931449%, transparent 0%);
#
#             }
#
#             #T_4e7a3ca2_4ca6_11e6_8b06_0c84dc86267brow6_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 50.0%, transparent 0%);
#
#             }
#
#             #T_4e7a3ca2_4ca6_11e6_8b06_0c84dc86267brow6_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 36.3636363636%, transparent 0%);
#
#             }
#
#             #T_4e7a3ca2_4ca6_11e6_8b06_0c84dc86267brow6_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 55.3818400481%, transparent 0%);
#
#             }
#
#             #T_4e7a3ca2_4ca6_11e6_8b06_0c84dc86267brow7_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 26.1363636364%, transparent 0%);
#
#             }
#
#             #T_4e7a3ca2_4ca6_11e6_8b06_0c84dc86267brow7_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 9.09090909091%, transparent 0%);
#
#             }
#
#             #T_4e7a3ca2_4ca6_11e6_8b06_0c84dc86267brow7_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 47.4443776308%, transparent 0%);
#
#             }
#
#             #T_4e7a3ca2_4ca6_11e6_8b06_0c84dc86267brow8_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 14.7727272727%, transparent 0%);
#
#             }
#
#             #T_4e7a3ca2_4ca6_11e6_8b06_0c84dc86267brow8_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_4e7a3ca2_4ca6_11e6_8b06_0c84dc86267brow8_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 36.5003006615%, transparent 0%);
#
#             }
#
#             #T_4e7a3ca2_4ca6_11e6_8b06_0c84dc86267brow9_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 26.136

# %% [markdown]
# ### マイナス域

# %%
compare_category.sort_values('diff',ascending=True).head(30).style.bar(subset=['succeed','normal','diff_abs'],color='#d65f5f')
# Out:
#         <style  type="text/css" >
#
#
#             #T_58a9f2ee_4ca6_11e6_8b06_0c84dc86267brow0_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 15.7894736842%, transparent 0%);
#
#             }
#
#             #T_58a9f2ee_4ca6_11e6_8b06_0c84dc86267brow0_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 40.7407407407%, transparent 0%);
#
#             }
#
#             #T_58a9f2ee_4ca6_11e6_8b06_0c84dc86267brow0_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#
#             }
#
#             #T_58a9f2ee_4ca6_11e6_8b06_0c84dc86267brow1_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 13.1578947368%, transparent 0%);
#
#             }
#
#             #T_58a9f2ee_4ca6_11e6_8b06_0c84dc86267brow1_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 33.3333333333%, transparent 0%);
#
#             }
#
#             #T_58a9f2ee_4ca6_11e6_8b06_0c84dc86267brow1_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 81.8003913894%, transparent 0%);
#
#             }
#
#             #T_58a9f2ee_4ca6_11e6_8b06_0c84dc86267brow2_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_58a9f2ee_4ca6_11e6_8b06_0c84dc86267brow2_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 14.8148148148%, transparent 0%);
#
#             }
#
#             #T_58a9f2ee_4ca6_11e6_8b06_0c84dc86267brow2_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 58.8062622309%, transparent 0%);
#
#             }
#
#             #T_58a9f2ee_4ca6_11e6_8b06_0c84dc86267brow3_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 9.21052631579%, transparent 0%);
#
#             }
#
#             #T_58a9f2ee_4ca6_11e6_8b06_0c84dc86267brow3_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 22.2222222222%, transparent 0%);
#
#             }
#
#             #T_58a9f2ee_4ca6_11e6_8b06_0c84dc86267brow3_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 54.5009784736%, transparent 0%);
#
#             }
#
#             #T_58a9f2ee_4ca6_11e6_8b06_0c84dc86267brow4_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_58a9f2ee_4ca6_11e6_8b06_0c84dc86267brow4_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 11.1111111111%, transparent 0%);
#
#             }
#
#             #T_58a9f2ee_4ca6_11e6_8b06_0c84dc86267brow4_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 45.2054794521%, transparent 0%);
#
#             }
#
#             #T_58a9f2ee_4ca6_11e6_8b06_0c84dc86267brow5_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 2.63157894737%, transparent 0%);
#
#             }
#
#             #T_58a9f2ee_4ca6_11e6_8b06_0c84dc86267brow5_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 11.1111111111%, transparent 0%);
#
#             }
#
#             #T_58a9f2ee_4ca6_11e6_8b06_0c84dc86267brow5_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 36.2035225049%, transparent 0%);
#
#             }
#
#             #T_58a9f2ee_4ca6_11e6_8b06_0c84dc86267brow6_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 11.8421052632%, transparent 0%);
#
#             }
#
#             #T_58a9f2ee_4ca6_11e6_8b06_0c84dc86267brow6_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 18.5185185185%, transparent 0%);
#
#             }
#
#             #T_58a9f2ee_4ca6_11e6_8b06_0c84dc86267brow6_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 31.8982387476%, transparent 0%);
#
#             }
#
#             #T_58a9f2ee_4ca6_11e6_8b06_0c84dc86267brow7_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 11.8421052632%, transparent 0%);
#
#             }
#
#             #T_58a9f2ee_4ca6_11e6_8b06_0c84dc86267brow7_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 18.5185185185%, transparent 0%);
#
#             }
#
#             #T_58a9f2ee_4ca6_11e6_8b06_0c84dc86267brow7_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 31.8982387476%, transparent 0%);
#
#             }
#
#             #T_58a9f2ee_4ca6_11e6_8b06_0c84dc86267brow8_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_58a9f2ee_4ca6_11e6_8b06_0c84dc86267brow8_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 7.40740740741%, transparent 0%);
#
#             }
#
#             #T_58a9f2ee_4ca6_11e6_8b06_0c84dc86267brow8_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 31.6046966732%, transparent 0%);
#
#             }
#
#             #T_58a9f2ee_4ca6_11e6_8b06_0c84dc86267brow9_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_58a9f2ee_4ca6_11e6_8b06_0c84dc86267brow9_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 7.407

# %% [markdown]
# ### 絶対値

# %%
compare_category[compare_category['diff_abs'] >= 0.2].sort_values('diff_abs',ascending=False).style.bar(subset=['succeed','normal','diff_abs'],color='#d65f5f')
# Out:
#         <style  type="text/css" >
#
#
#             #T_5b227910_4ca6_11e6_8b06_0c84dc86267brow0_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 12.1212121212%, transparent 0%);
#
#             }
#
#             #T_5b227910_4ca6_11e6_8b06_0c84dc86267brow0_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 52.9411764706%, transparent 0%);
#
#             }
#
#             #T_5b227910_4ca6_11e6_8b06_0c84dc86267brow0_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#
#             }
#
#             #T_5b227910_4ca6_11e6_8b06_0c84dc86267brow1_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 53.5353535354%, transparent 0%);
#
#             }
#
#             #T_5b227910_4ca6_11e6_8b06_0c84dc86267brow1_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_5b227910_4ca6_11e6_8b06_0c84dc86267brow1_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 92.7813163482%, transparent 0%);
#
#             }
#
#             #T_5b227910_4ca6_11e6_8b06_0c84dc86267brow2_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 70.7070707071%, transparent 0%);
#
#             }
#
#             #T_5b227910_4ca6_11e6_8b06_0c84dc86267brow2_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 17.6470588235%, transparent 0%);
#
#             }
#
#             #T_5b227910_4ca6_11e6_8b06_0c84dc86267brow2_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 87.2611464968%, transparent 0%);
#
#             }
#
#             #T_5b227910_4ca6_11e6_8b06_0c84dc86267brow3_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 10.101010101%, transparent 0%);
#
#             }
#
#             #T_5b227910_4ca6_11e6_8b06_0c84dc86267brow3_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 47.0588235294%, transparent 0%);
#
#             }
#
#             #T_5b227910_4ca6_11e6_8b06_0c84dc86267brow3_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 80.2547770701%, transparent 0%);
#
#             }
#
#             #T_5b227910_4ca6_11e6_8b06_0c84dc86267brow4_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 52.5252525253%, transparent 0%);
#
#             }
#
#             #T_5b227910_4ca6_11e6_8b06_0c84dc86267brow4_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 5.88235294118%, transparent 0%);
#
#             }
#
#             #T_5b227910_4ca6_11e6_8b06_0c84dc86267brow4_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 58.3864118896%, transparent 0%);
#
#             }
#
#             #T_5b227910_4ca6_11e6_8b06_0c84dc86267brow5_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_5b227910_4ca6_11e6_8b06_0c84dc86267brow5_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 32.3529411765%, transparent 0%);
#
#             }
#
#             #T_5b227910_4ca6_11e6_8b06_0c84dc86267brow5_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 55.3078556263%, transparent 0%);
#
#             }
#
#             #T_5b227910_4ca6_11e6_8b06_0c84dc86267brow6_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 7.07070707071%, transparent 0%);
#
#             }
#
#             #T_5b227910_4ca6_11e6_8b06_0c84dc86267brow6_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 38.2352941176%, transparent 0%);
#
#             }
#
#             #T_5b227910_4ca6_11e6_8b06_0c84dc86267brow6_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 50.6369426752%, transparent 0%);
#
#             }
#
#             #T_5b227910_4ca6_11e6_8b06_0c84dc86267brow7_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 46.4646464646%, transparent 0%);
#
#             }
#
#             #T_5b227910_4ca6_11e6_8b06_0c84dc86267brow7_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 2.94117647059%, transparent 0%);
#
#             }
#
#             #T_5b227910_4ca6_11e6_8b06_0c84dc86267brow7_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 43.8428874735%, transparent 0%);
#
#             }
#
#             #T_5b227910_4ca6_11e6_8b06_0c84dc86267brow8_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_5b227910_4ca6_11e6_8b06_0c84dc86267brow8_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 29.4117647059%, transparent 0%);
#
#             }
#
#             #T_5b227910_4ca6_11e6_8b06_0c84dc86267brow8_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 40.5520169851%, transparent 0%);
#
#             }
#
#             #T_5b227910_4ca6_11e6_8b06_0c84dc86267brow9_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 2.0202020202%, transparent 0%);
#
#             }
#
#             #T_5b227910_4ca6_11e6_8b06_0c84dc86267brow9_col2 {
#
#                 width:  10em;

# %% [markdown]
# ### 効果・価値

# %%
compare_category[compare_category.index.str.startswith("C01")].style.bar(subset=['succeed','normal','diff_abs'],color='#d65f5f')
# Out:
#         <style  type="text/css" >
#
#
#             #T_5d70ded2_4ca6_11e6_8b06_0c84dc86267brow0_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 5.71428571429%, transparent 0%);
#
#             }
#
#             #T_5d70ded2_4ca6_11e6_8b06_0c84dc86267brow0_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 13.3333333333%, transparent 0%);
#
#             }
#
#             #T_5d70ded2_4ca6_11e6_8b06_0c84dc86267brow0_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 4.45920303605%, transparent 0%);
#
#             }
#
#             #T_5d70ded2_4ca6_11e6_8b06_0c84dc86267brow1_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 1.42857142857%, transparent 0%);
#
#             }
#
#             #T_5d70ded2_4ca6_11e6_8b06_0c84dc86267brow1_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_5d70ded2_4ca6_11e6_8b06_0c84dc86267brow1_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 2.18216318786%, transparent 0%);
#
#             }
#
#             #T_5d70ded2_4ca6_11e6_8b06_0c84dc86267brow2_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 17.1428571429%, transparent 0%);
#
#             }
#
#             #T_5d70ded2_4ca6_11e6_8b06_0c84dc86267brow2_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 6.66666666667%, transparent 0%);
#
#             }
#
#             #T_5d70ded2_4ca6_11e6_8b06_0c84dc86267brow2_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 19.5920303605%, transparent 0%);
#
#             }
#
#             #T_5d70ded2_4ca6_11e6_8b06_0c84dc86267brow3_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#
#             }
#
#             #T_5d70ded2_4ca6_11e6_8b06_0c84dc86267brow3_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 53.3333333333%, transparent 0%);
#
#             }
#
#             #T_5d70ded2_4ca6_11e6_8b06_0c84dc86267brow3_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#
#             }
#
#             #T_5d70ded2_4ca6_11e6_8b06_0c84dc86267brow4_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 37.1428571429%, transparent 0%);
#
#             }
#
#             #T_5d70ded2_4ca6_11e6_8b06_0c84dc86267brow4_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 66.6666666667%, transparent 0%);
#
#             }
#
#             #T_5d70ded2_4ca6_11e6_8b06_0c84dc86267brow4_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 9.20303605313%, transparent 0%);
#
#             }
#
#             #T_5d70ded2_4ca6_11e6_8b06_0c84dc86267brow5_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 7.14285714286%, transparent 0%);
#
#             }
#
#             #T_5d70ded2_4ca6_11e6_8b06_0c84dc86267brow5_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 6.66666666667%, transparent 0%);
#
#             }
#
#             #T_5d70ded2_4ca6_11e6_8b06_0c84dc86267brow5_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 4.31688804554%, transparent 0%);
#
#             }
#
#             #T_5d70ded2_4ca6_11e6_8b06_0c84dc86267brow6_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 10.0%, transparent 0%);
#
#             }
#
#             #T_5d70ded2_4ca6_11e6_8b06_0c84dc86267brow6_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#
#             }
#
#             #T_5d70ded2_4ca6_11e6_8b06_0c84dc86267brow6_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 83.6337760911%, transparent 0%);
#
#             }
#
#             #T_5d70ded2_4ca6_11e6_8b06_0c84dc86267brow7_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 2.85714285714%, transparent 0%);
#
#             }
#
#             #T_5d70ded2_4ca6_11e6_8b06_0c84dc86267brow7_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_5d70ded2_4ca6_11e6_8b06_0c84dc86267brow7_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 4.36432637571%, transparent 0%);
#
#             }
#
#             #T_5d70ded2_4ca6_11e6_8b06_0c84dc86267brow8_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_5d70ded2_4ca6_11e6_8b06_0c84dc86267brow8_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_5d70ded2_4ca6_11e6_8b06_0c84dc86267brow8_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_5d70ded2_4ca6_11e6_8b06_0c84dc86267brow9_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 2.85714285714%, transparent 0%);
#
#             }
#
#             #T_5d70ded2_4ca6_11e6_8b06_0c84dc86267brow9_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 66.6666666667%, transparent 0%);
#
#             }
#
#             #T_5d70ded2_4ca6_11e6_8b06_0c84dc86267brow9_col4 {

# %% [markdown]
# ### 全体設計デザイン

# %%
compare_category[compare_category.index.str.startswith("D01")].style.bar(subset=['succeed','normal','diff_abs'],color='#d65f5f')
# Out:
#         <style  type="text/css" >
#
#
#             #T_5f5ab43e_4ca6_11e6_8b06_0c84dc86267brow0_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 66.6666666667%, transparent 0%);
#
#             }
#
#             #T_5f5ab43e_4ca6_11e6_8b06_0c84dc86267brow0_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#
#             }
#
#             #T_5f5ab43e_4ca6_11e6_8b06_0c84dc86267brow0_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 16.3043478261%, transparent 0%);
#
#             }
#
#             #T_5f5ab43e_4ca6_11e6_8b06_0c84dc86267brow1_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 16.6666666667%, transparent 0%);
#
#             }
#
#             #T_5f5ab43e_4ca6_11e6_8b06_0c84dc86267brow1_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#
#             }
#
#             #T_5f5ab43e_4ca6_11e6_8b06_0c84dc86267brow1_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 33.6956521739%, transparent 0%);
#
#             }
#
#             #T_5f5ab43e_4ca6_11e6_8b06_0c84dc86267brow2_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 25.0%, transparent 0%);
#
#             }
#
#             #T_5f5ab43e_4ca6_11e6_8b06_0c84dc86267brow2_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_5f5ab43e_4ca6_11e6_8b06_0c84dc86267brow2_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 25.0%, transparent 0%);
#
#             }
#
#             #T_5f5ab43e_4ca6_11e6_8b06_0c84dc86267brow3_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#
#             }
#
#             #T_5f5ab43e_4ca6_11e6_8b06_0c84dc86267brow3_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_5f5ab43e_4ca6_11e6_8b06_0c84dc86267brow3_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#
#             }
#
#             #T_5f5ab43e_4ca6_11e6_8b06_0c84dc86267brow4_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 16.6666666667%, transparent 0%);
#
#             }
#
#             #T_5f5ab43e_4ca6_11e6_8b06_0c84dc86267brow4_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#
#             }
#
#             #T_5f5ab43e_4ca6_11e6_8b06_0c84dc86267brow4_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 33.6956521739%, transparent 0%);
#
#             }
#
#             #T_5f5ab43e_4ca6_11e6_8b06_0c84dc86267brow5_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_5f5ab43e_4ca6_11e6_8b06_0c84dc86267brow5_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_5f5ab43e_4ca6_11e6_8b06_0c84dc86267brow5_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_5f5ab43e_4ca6_11e6_8b06_0c84dc86267brow6_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 16.6666666667%, transparent 0%);
#
#             }
#
#             #T_5f5ab43e_4ca6_11e6_8b06_0c84dc86267brow6_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_5f5ab43e_4ca6_11e6_8b06_0c84dc86267brow6_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 16.6666666667%, transparent 0%);
#
#             }
#
#             #T_5f5ab43e_4ca6_11e6_8b06_0c84dc86267brow7_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_5f5ab43e_4ca6_11e6_8b06_0c84dc86267brow7_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#
#             }
#
#             #T_5f5ab43e_4ca6_11e6_8b06_0c84dc86267brow7_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 50.3623188406%, transparent 0%);
#
#             }
#
#             #T_5f5ab43e_4ca6_11e6_8b06_0c84dc86267brow8_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 8.33333333333%, transparent 0%);
#
#             }
#
#             #T_5f5ab43e_4ca6_11e6_8b06_0c84dc86267brow8_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_5f5ab43e_4ca6_11e6_8b06_0c84dc86267brow8_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 8.33333333333%, transparent 0%);
#
#             }
#
#             #T_5f5ab43e_4ca6_11e6_8b06_0c84dc86267brow9_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_5f5ab43e_4ca6_11e6_8b06_0c84dc86267brow9_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_5f5ab43e_4ca6_11e6_8b06_0c84dc86267brow9_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_5f5ab43e_4ca6_11e6_8b06_0c84dc86267brow10_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_5f5ab43e_4ca6_11e6_8b06_0c84dc86267brow10_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 25.0%, transparent 0%);

# %% [markdown]
# ### モーションセンサー

# %%
compare_category[compare_category.index.str.startswith("F01")].style.bar(subset=['succeed','normal','diff_abs'],color='#d65f5f')
# Out:
#         <style  type="text/css" >
#
#
#             #T_615364c0_4ca6_11e6_8b06_0c84dc86267brow0_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_615364c0_4ca6_11e6_8b06_0c84dc86267brow0_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_615364c0_4ca6_11e6_8b06_0c84dc86267brow0_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_615364c0_4ca6_11e6_8b06_0c84dc86267brow1_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#
#             }
#
#             #T_615364c0_4ca6_11e6_8b06_0c84dc86267brow1_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#
#             }
#
#             #T_615364c0_4ca6_11e6_8b06_0c84dc86267brow1_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#
#             }
#
#             #T_615364c0_4ca6_11e6_8b06_0c84dc86267brow2_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 7.69230769231%, transparent 0%);
#
#             }
#
#             #T_615364c0_4ca6_11e6_8b06_0c84dc86267brow2_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_615364c0_4ca6_11e6_8b06_0c84dc86267brow2_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 3.41246290801%, transparent 0%);
#
#             }
#
#             #T_615364c0_4ca6_11e6_8b06_0c84dc86267brow3_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 30.7692307692%, transparent 0%);
#
#             }
#
#             #T_615364c0_4ca6_11e6_8b06_0c84dc86267brow3_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_615364c0_4ca6_11e6_8b06_0c84dc86267brow3_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 13.649851632%, transparent 0%);
#
#             }
#
#             #T_615364c0_4ca6_11e6_8b06_0c84dc86267brow4_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 46.1538461538%, transparent 0%);
#
#             }
#
#             #T_615364c0_4ca6_11e6_8b06_0c84dc86267brow4_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_615364c0_4ca6_11e6_8b06_0c84dc86267brow4_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 20.4747774481%, transparent 0%);
#
#             }
#
#             #T_615364c0_4ca6_11e6_8b06_0c84dc86267brow5_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 76.9230769231%, transparent 0%);
#
#             }
#
#             #T_615364c0_4ca6_11e6_8b06_0c84dc86267brow5_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 92.8571428571%, transparent 0%);
#
#             }
#
#             #T_615364c0_4ca6_11e6_8b06_0c84dc86267brow5_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 99.9258160237%, transparent 0%);
#
#             }
#
#             #T_615364c0_4ca6_11e6_8b06_0c84dc86267brow6_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 38.4615384615%, transparent 0%);
#
#             }
#
#             #T_615364c0_4ca6_11e6_8b06_0c84dc86267brow6_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 14.2857142857%, transparent 0%);
#
#             }
#
#             #T_615364c0_4ca6_11e6_8b06_0c84dc86267brow6_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 3.56083086053%, transparent 0%);
#
#             }
#
#             #T_615364c0_4ca6_11e6_8b06_0c84dc86267brow7_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 61.5384615385%, transparent 0%);
#
#             }
#
#             #T_615364c0_4ca6_11e6_8b06_0c84dc86267brow7_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 7.14285714286%, transparent 0%);
#
#             }
#
#             #T_615364c0_4ca6_11e6_8b06_0c84dc86267brow7_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 16.9881305638%, transparent 0%);
#
#             }
#
#         </style>
#
#         <table id="T_615364c0_4ca6_11e6_8b06_0c84dc86267b" None>
#
#
#         <thead>
#
#             <tr>
#
#                 <th class="blank">
#
#                 <th class="col_heading level0 col0">小区分
#
#                 <th class="col_heading level0 col1">succeed
#
#                 <th class="col_heading level0 col2">normal
#
#                 <th class="col_heading level0 col3">diff
#
#                 <th class="col_heading level0 col4">diff_abs
#
#                 <th class="col_heading level0 col5">pvalue
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#                 <th id="T_615364c0_4ca6_11e6_8b06_0c84dc86267b" class="row_heading level5 row0">
#                     F0101
#
#                 <td id="T_615364c0_4ca6_11e6_8b06_0c84dc86267brow0_col0" class="data row0 col0">
#                     振動
#
#                 <td id="T_615364c0_4ca6_11e6_8b06_0c84dc86267brow0_col1" class="data row0 col1">
#                     0
#
#                 <td id="T_615364c0_4ca6_11e6_8b06_0c84dc86267brow0_col2" class="data row0 col2">
#                     0
#
#                 <td id="T_615364c0_4ca6_11e6_8b06_0c84dc86267brow0_col3" class="data row0 col3">
#                     0
#
#                 <td id="T_615364c0_4ca6_11e6_8b06_0c84dc86267brow0_col4" class="data row0 col4">
#                     0
#
#                 <td id="

# %% [markdown]
# ### バイタルセンサー

# %%
compare_category[compare_category.index.str.startswith("F02")].style.bar(subset=['succeed','normal','diff_abs'],color='#d65f5f')
# Out:
#         <style  type="text/css" >
#
#
#             #T_639a95e6_4ca6_11e6_8b06_0c84dc86267brow0_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 45.4545454545%, transparent 0%);
#
#             }
#
#             #T_639a95e6_4ca6_11e6_8b06_0c84dc86267brow0_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#
#             }
#
#             #T_639a95e6_4ca6_11e6_8b06_0c84dc86267brow0_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 84.9574885546%, transparent 0%);
#
#             }
#
#             #T_639a95e6_4ca6_11e6_8b06_0c84dc86267brow1_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 72.7272727273%, transparent 0%);
#
#             }
#
#             #T_639a95e6_4ca6_11e6_8b06_0c84dc86267brow1_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 9.09090909091%, transparent 0%);
#
#             }
#
#             #T_639a95e6_4ca6_11e6_8b06_0c84dc86267brow1_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 14.9771092217%, transparent 0%);
#
#             }
#
#             #T_639a95e6_4ca6_11e6_8b06_0c84dc86267brow2_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 18.1818181818%, transparent 0%);
#
#             }
#
#             #T_639a95e6_4ca6_11e6_8b06_0c84dc86267brow2_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 18.1818181818%, transparent 0%);
#
#             }
#
#             #T_639a95e6_4ca6_11e6_8b06_0c84dc86267brow2_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 12.1648136037%, transparent 0%);
#
#             }
#
#             #T_639a95e6_4ca6_11e6_8b06_0c84dc86267brow3_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 18.1818181818%, transparent 0%);
#
#             }
#
#             #T_639a95e6_4ca6_11e6_8b06_0c84dc86267brow3_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 18.1818181818%, transparent 0%);
#
#             }
#
#             #T_639a95e6_4ca6_11e6_8b06_0c84dc86267brow3_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 12.1648136037%, transparent 0%);
#
#             }
#
#             #T_639a95e6_4ca6_11e6_8b06_0c84dc86267brow4_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_639a95e6_4ca6_11e6_8b06_0c84dc86267brow4_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#
#             }
#
#             #T_639a95e6_4ca6_11e6_8b06_0c84dc86267brow4_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#
#             }
#
#             #T_639a95e6_4ca6_11e6_8b06_0c84dc86267brow5_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 18.1818181818%, transparent 0%);
#
#             }
#
#             #T_639a95e6_4ca6_11e6_8b06_0c84dc86267brow5_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_639a95e6_4ca6_11e6_8b06_0c84dc86267brow5_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 6.01700457816%, transparent 0%);
#
#             }
#
#             #T_639a95e6_4ca6_11e6_8b06_0c84dc86267brow6_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 54.5454545455%, transparent 0%);
#
#             }
#
#             #T_639a95e6_4ca6_11e6_8b06_0c84dc86267brow6_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_639a95e6_4ca6_11e6_8b06_0c84dc86267brow6_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 18.0510137345%, transparent 0%);
#
#             }
#
#             #T_639a95e6_4ca6_11e6_8b06_0c84dc86267brow7_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_639a95e6_4ca6_11e6_8b06_0c84dc86267brow7_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_639a95e6_4ca6_11e6_8b06_0c84dc86267brow7_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_639a95e6_4ca6_11e6_8b06_0c84dc86267brow8_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 90.9090909091%, transparent 0%);
#
#             }
#
#             #T_639a95e6_4ca6_11e6_8b06_0c84dc86267brow8_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 45.4545454545%, transparent 0%);
#
#             }
#
#             #T_639a95e6_4ca6_11e6_8b06_0c84dc86267brow8_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 15.3695225638%, transparent 0%);
#
#             }
#
#             #T_639a95e6_4ca6_11e6_8b06_0c84dc86267brow9_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#
#             }
#
#             #T_639a95e6_4ca6_11e6_8b06_0c84dc86267brow9_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#
#             }
#
#             #T_639a95e6_4ca6_11e6_8b06_0c84dc86267brow9_col4 {
#
#                 width:  10em;
#
#                  height:  80%;

# %% [markdown]
# ### 医療用途

# %%
compare_category[compare_category.index.str.startswith("H02")].style.bar(subset=['succeed','normal','diff_abs'],color='#d65f5f')
# Out:
#         <style  type="text/css" >
#
#
#             #T_64fa719a_4ca6_11e6_8b06_0c84dc86267brow0_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#
#             }
#
#             #T_64fa719a_4ca6_11e6_8b06_0c84dc86267brow0_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f nan%, transparent 0%);
#
#             }
#
#             #T_64fa719a_4ca6_11e6_8b06_0c84dc86267brow0_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#
#             }
#
#             #T_64fa719a_4ca6_11e6_8b06_0c84dc86267brow1_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_64fa719a_4ca6_11e6_8b06_0c84dc86267brow1_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f nan%, transparent 0%);
#
#             }
#
#             #T_64fa719a_4ca6_11e6_8b06_0c84dc86267brow1_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_64fa719a_4ca6_11e6_8b06_0c84dc86267brow2_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 28.5714285714%, transparent 0%);
#
#             }
#
#             #T_64fa719a_4ca6_11e6_8b06_0c84dc86267brow2_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f nan%, transparent 0%);
#
#             }
#
#             #T_64fa719a_4ca6_11e6_8b06_0c84dc86267brow2_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 28.5714285714%, transparent 0%);
#
#             }
#
#             #T_64fa719a_4ca6_11e6_8b06_0c84dc86267brow3_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_64fa719a_4ca6_11e6_8b06_0c84dc86267brow3_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f nan%, transparent 0%);
#
#             }
#
#             #T_64fa719a_4ca6_11e6_8b06_0c84dc86267brow3_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#         </style>
#
#         <table id="T_64fa719a_4ca6_11e6_8b06_0c84dc86267b" None>
#
#
#         <thead>
#
#             <tr>
#
#                 <th class="blank">
#
#                 <th class="col_heading level0 col0">小区分
#
#                 <th class="col_heading level0 col1">succeed
#
#                 <th class="col_heading level0 col2">normal
#
#                 <th class="col_heading level0 col3">diff
#
#                 <th class="col_heading level0 col4">diff_abs
#
#                 <th class="col_heading level0 col5">pvalue
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#                 <th id="T_64fa719a_4ca6_11e6_8b06_0c84dc86267b" class="row_heading level5 row0">
#                     H0201
#
#                 <td id="T_64fa719a_4ca6_11e6_8b06_0c84dc86267brow0_col0" class="data row0 col0">
#                     医療
#
#                 <td id="T_64fa719a_4ca6_11e6_8b06_0c84dc86267brow0_col1" class="data row0 col1">
#                     0.0503597
#
#                 <td id="T_64fa719a_4ca6_11e6_8b06_0c84dc86267brow0_col2" class="data row0 col2">
#                     0
#
#                 <td id="T_64fa719a_4ca6_11e6_8b06_0c84dc86267brow0_col3" class="data row0 col3">
#                     0.0503597
#
#                 <td id="T_64fa719a_4ca6_11e6_8b06_0c84dc86267brow0_col4" class="data row0 col4">
#                     0.0503597
#
#                 <td id="T_64fa719a_4ca6_11e6_8b06_0c84dc86267brow0_col5" class="data row0 col5">
#                     0.120744
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_64fa719a_4ca6_11e6_8b06_0c84dc86267b" class="row_heading level5 row1">
#                     H0202
#
#                 <td id="T_64fa719a_4ca6_11e6_8b06_0c84dc86267brow1_col0" class="data row1 col0">
#                     介護・障がい者支援
#
#                 <td id="T_64fa719a_4ca6_11e6_8b06_0c84dc86267brow1_col1" class="data row1 col1">
#                     0
#
#                 <td id="T_64fa719a_4ca6_11e6_8b06_0c84dc86267brow1_col2" class="data row1 col2">
#                     0
#
#                 <td id="T_64fa719a_4ca6_11e6_8b06_0c84dc86267brow1_col3" class="data row1 col3">
#                     0
#
#                 <td id="T_64fa719a_4ca6_11e6_8b06_0c84dc86267brow1_col4" class="data row1 col4">
#                     0
#
#                 <td id="T_64fa719a_4ca6_11e6_8b06_0c84dc86267brow1_col5" class="data row1 col5">
#                     nan
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_64fa719a_4ca6_11e6_8b06_0c84dc86267b" class="row_heading level5 row2">
#                     H0298
#
#                 <td id="T_64fa719a_4ca6_11e6_8b06_0c84dc86267brow2_col0" class="data row2 col0">
#                     医療介護用途に関し非限定
#
#                 <td id="T_64fa719a_4ca6_11e6_8b06_0c84dc86267brow2_col1" class="data row2 col1">
#                     0.0143885
#
#                 <td id="T_64fa719a_4ca6_11e6_8b06_0c84dc86267brow2_col2" class="data row2 col2">
#                     0
#
#                 <td id="T_64fa719a_4ca6_11e6_8b06_0c84dc86267brow2_col3" class="data row2 col3">
#                     0.0143885
#
#                 <td id="T_64fa719a_4ca6_11e6_8b06_0c84dc86267brow2_col4" class="data row2 col4">
#                     0.0143885
#
#                 <td id="T_64fa719a_4ca6_11e6_8b06_0c84dc86267brow2_col5" class="data row2 col5">
#                     0.413364
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_64fa719a_4ca6_11e6_8b06_0c84dc86267b" class="row_heading level5 row3">
#                     H0299
#
#                 <td id="T_64fa719a_4ca6_11e6_8b06_0c84dc86267brow3_col0" class="data row3 col0">
#                     その他の医療介護用途
#
#                 <td id="T_64fa719a_4ca6_11e6_8b06_0c84dc86267brow3_col1" class="data row3 col1">
#                     0
#
#                 <td id="T_64fa719a_4ca6_11e6_8b06_0c84dc86267brow3_col2" class="data row3 col2">
#                     0
#
#                 <td id="T_64fa719a_4ca6_11e6_8b06_0c84dc86267brow3_col3" class="data row3 col3">
#                     0
#
#                 <td id="T_64fa719a_4ca6_11e6_8b06_0c84dc86267brow3_col4" class="data row3 col4">
#                     0
#
#                 <td id="T_64fa719a_4ca6_11e6_8b06_0c84dc86267brow3_col5" class="data row3 col5">
#                     nan
#
#             </tr>
#
#         </tbo

# %% [markdown]
# ### ヘルスケア用途

# %%
compare_category[compare_category.index.str.startswith("H03")].style.bar(subset=['succeed','normal','diff_abs'],color='#d65f5f')
# Out:
#         <style  type="text/css" >
#
#
#             #T_66c17e88_4ca6_11e6_8b06_0c84dc86267brow0_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_66c17e88_4ca6_11e6_8b06_0c84dc86267brow0_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 16.6666666667%, transparent 0%);
#
#             }
#
#             #T_66c17e88_4ca6_11e6_8b06_0c84dc86267brow0_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 17.6395939086%, transparent 0%);
#
#             }
#
#             #T_66c17e88_4ca6_11e6_8b06_0c84dc86267brow1_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#
#             }
#
#             #T_66c17e88_4ca6_11e6_8b06_0c84dc86267brow1_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#
#             }
#
#             #T_66c17e88_4ca6_11e6_8b06_0c84dc86267brow1_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#
#             }
#
#             #T_66c17e88_4ca6_11e6_8b06_0c84dc86267brow2_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_66c17e88_4ca6_11e6_8b06_0c84dc86267brow2_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_66c17e88_4ca6_11e6_8b06_0c84dc86267brow2_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_66c17e88_4ca6_11e6_8b06_0c84dc86267brow3_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_66c17e88_4ca6_11e6_8b06_0c84dc86267brow3_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_66c17e88_4ca6_11e6_8b06_0c84dc86267brow3_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_66c17e88_4ca6_11e6_8b06_0c84dc86267brow4_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_66c17e88_4ca6_11e6_8b06_0c84dc86267brow4_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_66c17e88_4ca6_11e6_8b06_0c84dc86267brow4_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_66c17e88_4ca6_11e6_8b06_0c84dc86267brow5_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_66c17e88_4ca6_11e6_8b06_0c84dc86267brow5_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_66c17e88_4ca6_11e6_8b06_0c84dc86267brow5_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#         </style>
#
#         <table id="T_66c17e88_4ca6_11e6_8b06_0c84dc86267b" None>
#
#
#         <thead>
#
#             <tr>
#
#                 <th class="blank">
#
#                 <th class="col_heading level0 col0">小区分
#
#                 <th class="col_heading level0 col1">succeed
#
#                 <th class="col_heading level0 col2">normal
#
#                 <th class="col_heading level0 col3">diff
#
#                 <th class="col_heading level0 col4">diff_abs
#
#                 <th class="col_heading level0 col5">pvalue
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#                 <th id="T_66c17e88_4ca6_11e6_8b06_0c84dc86267b" class="row_heading level5 row0">
#                     H0301
#
#                 <td id="T_66c17e88_4ca6_11e6_8b06_0c84dc86267brow0_col0" class="data row0 col0">
#                     美容
#
#                 <td id="T_66c17e88_4ca6_11e6_8b06_0c84dc86267brow0_col1" class="data row0 col1">
#                     0
#
#                 <td id="T_66c17e88_4ca6_11e6_8b06_0c84dc86267brow0_col2" class="data row0 col2">
#                     0.0434783
#
#                 <td id="T_66c17e88_4ca6_11e6_8b06_0c84dc86267brow0_col3" class="data row0 col3">
#                     -0.0434783
#
#                 <td id="T_66c17e88_4ca6_11e6_8b06_0c84dc86267brow0_col4" class="data row0 col4">
#                     0.0434783
#
#                 <td id="T_66c17e88_4ca6_11e6_8b06_0c84dc86267brow0_col5" class="data row0 col5">
#                     0.0134455
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_66c17e88_4ca6_11e6_8b06_0c84dc86267b" class="row_heading level5 row1">
#                     H0302
#
#                 <td id="T_66c17e88_4ca6_11e6_8b06_0c84dc86267brow1_col0" class="data row1 col0">
#                     健康
#
#                 <td id="T_66c17e88_4ca6_11e6_8b06_0c84dc86267brow1_col1" class="data row1 col1">
#                     0.0143885
#
#                 <td id="T_66c17e88_4ca6_11e6_8b06_0c84dc86267brow1_col2" class="data row1 col2">
#                     0.26087
#
#                 <td id="T_66c17e88_4ca6_11e6_8b06_0c84dc86267brow1_col3" class="data row1 col3">
#                     -0.246481
#
#                 <td id="T_66c17e88_4ca6_11e6_8b06_0c84dc86267brow1_col4" class="data row1 col4">
#                     0.246481
#
#                 <td id="T_66c17e88_4ca6_11e6_8b06_0c84dc86267brow1_col5" class="data row1 col5">
#                     4.27969e-08
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_66c17e88_4ca6_11e6_8b06_0c84dc86267b" class="row_heading level5 row2">
#                     H0303
#
#                 <td id="T_66c17e88_4ca6_11e6_8b06_0c84dc86267brow2_col0" class="data row2 col0">
#                     生活記録
#
#                 <td id="T_66c17e88_4ca6_11e6_8b06_0c84dc86267brow2_col1" class="data row2 col1">
#                     0
#
#                 <td id="T_66c17e88_4ca6_11e6_8b06_0c84dc86267brow2_col2" class="data row2 col2">
#                     0
#
#                 <td id="T_66c17e88_4ca6_11e6_8b06_0c84dc86267brow2_col3" class="data row2 col3">
#                     0
#
#                 <td id="T_66c17e88_4ca6_11e6_8b06_0c84dc86267brow2_col4" class="data row2 col4">
#                     0
#
#                 <td id="T_66c17e88_4ca6_11e6_8b06_0c84dc86267brow2_col5" class="data row2 col5">
#                     nan
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_66c17e88_4ca6_11e6_8b06_0c84dc86267b" class="row_heading level5 row3">
#                     H0304
#
#                 <td id="T_66c17e88_4ca6_11e

# %% [markdown]
# ### スポーツ用途

# %%
compare_category[compare_category.index.str.startswith("H04")].style.bar(subset=['succeed','normal','diff_abs'],color='#d65f5f')
# Out:
#         <style  type="text/css" >
#
#
#             #T_6817c184_4ca6_11e6_8b06_0c84dc86267brow0_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f nan%, transparent 0%);
#
#             }
#
#             #T_6817c184_4ca6_11e6_8b06_0c84dc86267brow0_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 50.0%, transparent 0%);
#
#             }
#
#             #T_6817c184_4ca6_11e6_8b06_0c84dc86267brow0_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 50.0%, transparent 0%);
#
#             }
#
#             #T_6817c184_4ca6_11e6_8b06_0c84dc86267brow1_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f nan%, transparent 0%);
#
#             }
#
#             #T_6817c184_4ca6_11e6_8b06_0c84dc86267brow1_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_6817c184_4ca6_11e6_8b06_0c84dc86267brow1_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_6817c184_4ca6_11e6_8b06_0c84dc86267brow2_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f nan%, transparent 0%);
#
#             }
#
#             #T_6817c184_4ca6_11e6_8b06_0c84dc86267brow2_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_6817c184_4ca6_11e6_8b06_0c84dc86267brow2_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_6817c184_4ca6_11e6_8b06_0c84dc86267brow3_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f nan%, transparent 0%);
#
#             }
#
#             #T_6817c184_4ca6_11e6_8b06_0c84dc86267brow3_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#
#             }
#
#             #T_6817c184_4ca6_11e6_8b06_0c84dc86267brow3_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#
#             }
#
#             #T_6817c184_4ca6_11e6_8b06_0c84dc86267brow4_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f nan%, transparent 0%);
#
#             }
#
#             #T_6817c184_4ca6_11e6_8b06_0c84dc86267brow4_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_6817c184_4ca6_11e6_8b06_0c84dc86267brow4_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_6817c184_4ca6_11e6_8b06_0c84dc86267brow5_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f nan%, transparent 0%);
#
#             }
#
#             #T_6817c184_4ca6_11e6_8b06_0c84dc86267brow5_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_6817c184_4ca6_11e6_8b06_0c84dc86267brow5_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_6817c184_4ca6_11e6_8b06_0c84dc86267brow6_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f nan%, transparent 0%);
#
#             }
#
#             #T_6817c184_4ca6_11e6_8b06_0c84dc86267brow6_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_6817c184_4ca6_11e6_8b06_0c84dc86267brow6_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_6817c184_4ca6_11e6_8b06_0c84dc86267brow7_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f nan%, transparent 0%);
#
#             }
#
#             #T_6817c184_4ca6_11e6_8b06_0c84dc86267brow7_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_6817c184_4ca6_11e6_8b06_0c84dc86267brow7_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_6817c184_4ca6_11e6_8b06_0c84dc86267brow8_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f nan%, transparent 0%);
#
#             }
#
#             #T_6817c184_4ca6_11e6_8b06_0c84dc86267brow8_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_6817c184_4ca6_11e6_8b06_0c84dc86267brow8_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_6817c184_4ca6_11e6_8b06_0c84dc86267brow9_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f nan%, transparent 0%);
#
#             }
#
#             #T_6817c184_4ca6_11e6_8b06_0c84dc86267brow9_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_6817c184_4ca6_11e6_8b06_0c84dc86267brow9_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_6817c184_4ca6_11e6_8b06_0c84dc86267brow10_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f nan%, transparent 0%);
#
#             }
#
#             #T_6817c184_4ca6_11e6_8b06_0c84dc86267brow10_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_6817c184_4ca6_11e6_8b06_0c84dc86267brow10_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#         </style>
#
#         <table id="T_6817c184_4ca6_11e6_8b06_0c84dc86267b" None>
#
#
#         <thead>
#
#             <tr>
#
#                 <th class="blank">
#
#                 <th class="col_heading level0 col0">小区分
#
#                 <th class="col_heading level0 col1">succeed
#
#                 <

# %% [markdown]
# ### バイタルデータ

# %%
compare_category[compare_category.index.str.startswith("I07")].style.bar(subset=['succeed','normal','diff_abs'],color='#d65f5f')
# Out:
#         <style  type="text/css" >
#
#
#             #T_6a220dd6_4ca6_11e6_8b06_0c84dc86267brow0_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_6a220dd6_4ca6_11e6_8b06_0c84dc86267brow0_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 40.0%, transparent 0%);
#
#             }
#
#             #T_6a220dd6_4ca6_11e6_8b06_0c84dc86267brow0_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 40.0%, transparent 0%);
#
#             }
#
#             #T_6a220dd6_4ca6_11e6_8b06_0c84dc86267brow1_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 40.0%, transparent 0%);
#
#             }
#
#             #T_6a220dd6_4ca6_11e6_8b06_0c84dc86267brow1_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 40.0%, transparent 0%);
#
#             }
#
#             #T_6a220dd6_4ca6_11e6_8b06_0c84dc86267brow1_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 26.7625899281%, transparent 0%);
#
#             }
#
#             #T_6a220dd6_4ca6_11e6_8b06_0c84dc86267brow2_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_6a220dd6_4ca6_11e6_8b06_0c84dc86267brow2_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 60.0%, transparent 0%);
#
#             }
#
#             #T_6a220dd6_4ca6_11e6_8b06_0c84dc86267brow2_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 60.0%, transparent 0%);
#
#             }
#
#             #T_6a220dd6_4ca6_11e6_8b06_0c84dc86267brow3_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_6a220dd6_4ca6_11e6_8b06_0c84dc86267brow3_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_6a220dd6_4ca6_11e6_8b06_0c84dc86267brow3_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_6a220dd6_4ca6_11e6_8b06_0c84dc86267brow4_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_6a220dd6_4ca6_11e6_8b06_0c84dc86267brow4_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_6a220dd6_4ca6_11e6_8b06_0c84dc86267brow4_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_6a220dd6_4ca6_11e6_8b06_0c84dc86267brow5_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_6a220dd6_4ca6_11e6_8b06_0c84dc86267brow5_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_6a220dd6_4ca6_11e6_8b06_0c84dc86267brow5_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_6a220dd6_4ca6_11e6_8b06_0c84dc86267brow6_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_6a220dd6_4ca6_11e6_8b06_0c84dc86267brow6_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_6a220dd6_4ca6_11e6_8b06_0c84dc86267brow6_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_6a220dd6_4ca6_11e6_8b06_0c84dc86267brow7_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_6a220dd6_4ca6_11e6_8b06_0c84dc86267brow7_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_6a220dd6_4ca6_11e6_8b06_0c84dc86267brow7_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_6a220dd6_4ca6_11e6_8b06_0c84dc86267brow8_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_6a220dd6_4ca6_11e6_8b06_0c84dc86267brow8_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_6a220dd6_4ca6_11e6_8b06_0c84dc86267brow8_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_6a220dd6_4ca6_11e6_8b06_0c84dc86267brow9_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_6a220dd6_4ca6_11e6_8b06_0c84dc86267brow9_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 40.0%, transparent 0%);
#
#             }
#
#             #T_6a220dd6_4ca6_11e6_8b06_0c84dc86267brow9_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 40.0%, transparent 0%);
#
#             }
#
#             #T_6a220dd6_4ca6_11e6_8b06_0c84dc86267brow10_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#
#             }
#
#             #T_6a220dd6_4ca6_11e6_8b06_0c84dc86267brow10_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 60.0%, transparent 0%);
#
#             }
#
#             #T_6a220dd6_4ca6_11e6_8b06_0c84dc86267brow10_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 26.9064748201%, transparent 0%);
#
#             }
#
#             #T_6a220dd6_4ca6_11e6_8b06_0c84dc86267brow11_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_6a220dd6_4ca6_11e6_8b06_0c84dc86267brow11_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#
#             }
#
#             #T_6a220dd6_4ca6_11e6_8b06_0c84dc86267brow11_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
